# %%
import sqlite3
import pandas as pd

import sqlite3

def crear_tabla_proveedores():
    # Conexión a la base de datos existente
    conn = sqlite3.connect('piezas.db')
    cursor = conn.cursor()

# %%
def crear_tabla_pieza(conn):
    """Crear la tabla Pieza"""
    try:
        cursor = conn.cursor()
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS Pieza (
            ID INTEGER PRIMARY KEY AUTOINCREMENT,
            Nombre TEXT NOT NULL,
            Color TEXT,
            Precio REAL,
            ID_Categoria INTEGER
        );
        """)
        print("Tabla 'Pieza' creada exitosamente")
    except Error as e:
        print(e)

# %%
def insertar_piezas(conn):
    """Insertar las 50 piezas de ejemplo"""
    piezas = [
        ('Tornillo hexagonal', 'Plateado', 0.50, 1),
        ('Tuerca estándar', 'Plateado', 0.30, 1),
        ('Arandela plana', 'Plateado', 0.20, 1),
        ('Resorte helicoidal', 'Plateado', 1.20, 2),
        ('Junta tórica', 'Negro', 0.80, 3),
        ('Correa dentada', 'Negro', 5.99, 4),
        ('Rodamiento de bolas', 'Gris', 8.50, 5),
        ('Engranaje recto', 'Plateado', 3.75, 6),
        ('Eje de transmisión', 'Negro', 12.00, 7),
        ('Buje de bronce', 'Dorado', 4.25, 8),
        ('Válvula de retención', 'Rojo', 7.80, 9),
        ('Sensor de temperatura', 'Blanco', 15.99, 10),
        ('Cable eléctrico', 'Negro', 2.50, 11),
        ('Conector RJ45', 'Azul', 1.20, 12),
        ('Placa base', 'Verde', 25.00, 13),
        ('Disipador de calor', 'Negro', 6.40, 14),
        ('Ventilador axial', 'Negro', 9.99, 15),
        ('Filtro de aire', 'Blanco', 3.25, 16),
        ('Bomba de agua', 'Negro', 18.50, 17),
        ('Termostato', 'Blanco', 7.20, 18),
        ('Interruptor de palanca', 'Rojo', 2.10, 19),
        ('Fusible 10A', 'Amarillo', 0.75, 20),
        ('LED rojo', 'Rojo', 0.30, 21),
        ('Motor paso a paso', 'Negro', 22.00, 22),
        ('Reductor de velocidad', 'Gris', 35.00, 23),
        ('Correa trapezoidal', 'Negro', 4.80, 4),
        ('Polea dentada', 'Plateado', 6.20, 6),
        ('Soporte angular', 'Negro', 3.50, 24),
        ('Guía lineal', 'Plateado', 28.00, 25),
        ('Carril de rodadura', 'Gris', 19.99, 26),
        ('Cojinete de agujas', 'Plateado', 5.60, 5),
        ('Acoplador flexible', 'Negro', 8.25, 27),
        ('Sello mecánico', 'Negro', 6.80, 3),
        ('Cilindro neumático', 'Plateado', 24.50, 28),
        ('Válvula solenoide', 'Azul', 16.75, 9),
        ('Manómetro analógico', 'Blanco', 11.20, 29),
        ('Transductor de presión', 'Gris', 32.00, 30),
        ('Termopar tipo K', 'Amarillo', 9.40, 31),
        ('Convertidor de señal', 'Negro', 18.90, 32),
        ('Relé de potencia', 'Negro', 5.60, 33),
        ('Condensador electrolítico', 'Azul', 1.20, 34),
        ('Resistencia 10KΩ', 'Café', 0.15, 35),
        ('Potenciómetro lineal', 'Gris', 2.80, 36),
        ('Display 7 segmentos', 'Verde', 1.90, 37),
        ('Zócalo IC', 'Negro', 0.40, 38),
        ('Placa de circuito', 'Verde', 3.20, 13),
        ('Conector USB', 'Negro', 1.75, 12),
        ('Transformador 12V', 'Negro', 8.90, 39),
        ('Fuente de alimentación', 'Negro', 15.00, 40),
        ('Batería 9V', 'Negro', 4.50, 41)
    ]
    
    try:
        cursor = conn.cursor()
        cursor.executemany("INSERT INTO Pieza (Nombre, Color, Precio, ID_Categoria) VALUES (?, ?, ?, ?)", piezas)
        conn.commit()
        print(f"Se insertaron {len(piezas)} piezas correctamente")
    except Error as e:
        print(e)

# %%
def consultar_piezas(conn):
    """Consultar todas las piezas para verificación"""
    try:
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM Pieza")
        rows = cursor.fetchall()
        
        print("\nListado de piezas:")
        print("ID | Nombre | Color | Precio | ID_Categoria")
        print("-" * 50)
        for row in rows:
            print(f"{row[0]} | {row[1]} | {row[2]} | {row[3]} | {row[4]}")
        
        print(f"\nTotal de piezas: {len(rows)}")
    except Error as e:
        print(e)

# %%
def main():
    
    database = "database_team_5.db"
    
    
    conn = crear_conexion(database)
    
    if conn is not None:
     
        crear_tabla_pieza(conn)
        
    
        insertar_piezas(conn)
        
      
        consultar_piezas(conn)
        
    
        conn.close()
        print("\nConexión cerrada")
    else:
        print("Error al conectar con la base de datos")

if __name__ == '__main__':
    main()
# Out:
# Conexión exitosa a SQLite versión 2.6.0
# Tabla 'Pieza' creada exitosamente
# Se insertaron 50 piezas correctamente
#
# Listado de piezas:
# ID | Nombre | Color | Precio | ID_Categoria
# --------------------------------------------------
# 1 | Tornillo hexagonal | Plateado | 0.5 | 1
# 2 | Tuerca estándar | Plateado | 0.3 | 1
# 3 | Arandela plana | Plateado | 0.2 | 1
# 4 | Resorte helicoidal | Plateado | 1.2 | 2
# 5 | Junta tórica | Negro | 0.8 | 3
# 6 | Correa dentada | Negro | 5.99 | 4
# 7 | Rodamiento de bolas | Gris | 8.5 | 5
# 8 | Engranaje recto | Plateado | 3.75 | 6
# 9 | Eje de transmisión | Negro | 12.0 | 7
# 10 | Buje de bronce | Dorado | 4.25 | 8
# 11 | Válvula de retención | Rojo | 7.8 | 9
# 12 | Sensor de temperatura | Blanco | 15.99 | 10
# 13 | Cable eléctrico | Negro | 2.5 | 11
# 14 | Conector RJ45 | Azul | 1.2 | 12
# 15 | Placa base | Verde | 25.0 | 13
# 16 | Disipador de calor | Negro | 6.4 | 14
# 17 | Ventilador axial | Negro | 9.99 | 15
# 18 | Filtro de aire | Blanco | 3.25 | 16
# 19 | Bomba de agua | Negro | 18.5 | 17
# 20 | Termostato | Blanco | 7.2 | 18
# 21 | Interruptor de palanca | Rojo | 2.1 | 19
# 22 | Fusible 10A | Amarillo | 0.75 | 20
# 23 | LED rojo | Rojo | 0.3 | 21
# 24 | Motor paso a paso | Negro | 22.0 | 22
# 25 | Reductor de velocidad | Gris | 35.0 | 23
# 26 | Correa trapezoidal | Negro | 4.8 | 4
# 27 | Polea dentada | Plateado | 6.2 | 6
# 28 | Soporte angular | Negro | 3.5 | 24
# 29 | Guía lineal | Plateado | 28.0 | 25
# 30 | Carril de rodadura | Gris | 19.99 | 26
# 31 | Cojinete de agujas | Plateado | 5.6 | 5
# 32 | Acoplador flexible | Negro | 8.25 | 27
# 33 | Sello mecánico | Negro | 6.8 | 3
# 34 | Cilindro neumático | Plateado | 24.5 | 28
# 35 | Válvula solenoide | Azul | 16.75 | 9
# 36 | Manómetro analógico | Blanco | 11.2 | 29
# 37 | Transductor de presión | Gris | 32.0 | 30
# 38 | Termopar tipo K | Amarillo | 9.4 | 31
# 39 | Convertidor de señal | Negro | 18.9 | 32
# 40 | Relé de potencia | Negro | 5.6 | 33
# 41 | Condensador electrolítico | Azul | 1.2 | 34
# 42 | Resistencia 10KΩ | Café | 0.15 | 35
# 43 | Potenciómetro lineal | Gris | 2.8 | 36
# 44 | Display 7 segmentos | Verde | 1.9 | 37
# 45 | Zócalo IC | Negro | 0.4 | 38
# 46 | Placa de circuito | Verde | 3.2 | 13
# 47 | Conector USB | Negro | 1.75 | 12
# 48 | Transformador 12V | Negro | 8.9 | 39
# 49 | Fuente de alimentación | Negro | 15.0 | 40
# 50 | Batería 9V | Negro | 4.5 | 41
#
# Total de piezas: 50
#
# Conexión cerrada
# C:\Users\david\AppData\Local\Temp\ipykernel_2236\2024067570.py:9: DeprecationWarning: version is deprecated and will be removed in Python 3.14
#   print(f"Conexión exitosa a SQLite versión {sqlite3.version}")

# %%
conn = sqlite3.connect('database_team_5.db') 
query = "SELECT * FROM Pieza"
df = pd.read_sql_query(query, conn)
df
# Out:
#     ID                     Nombre     Color  Precio  ID_Categoria
# 0    1         Tornillo hexagonal  Plateado    0.50             1
# 1    2            Tuerca estándar  Plateado    0.30             1
# 2    3             Arandela plana  Plateado    0.20             1
# 3    4         Resorte helicoidal  Plateado    1.20             2
# 4    5               Junta tórica     Negro    0.80             3
# 5    6             Correa dentada     Negro    5.99             4
# 6    7        Rodamiento de bolas      Gris    8.50             5
# 7    8            Engranaje recto  Plateado    3.75             6
# 8    9         Eje de transmisión     Negro   12.00             7
# 9   10             Buje de bronce    Dorado    4.25             8
# 10  11       Válvula de retención      Rojo    7.80             9
# 11  12      Sensor de temperatura    Blanco   15.99            10
# 12  13            Cable eléctrico     Negro    2.50            11
# 13  14              Conector RJ45      Azul    1.20            12
# 14  15                 Placa base     Verde   25.00            13
# 15  16         Disipador de calor     Negro    6.40            14
# 16  17           Ventilador axial     Negro    9.99            15
# 17  18             Filtro de aire    Blanco    3.25            16
# 18  19              Bomba de agua     Negro   18.50            17
# 19  20                 Termostato    Blanco    7.20            18
# 20  21     Interruptor de palanca      Rojo    2.10            19
# 21  22                Fusible 10A  Amarillo    0.75            20
# 22  23                   LED rojo      Rojo    0.30            21
# 23  24          Motor paso a paso     Negro   22.00            22
# 24  25      Reductor de velocidad      Gris   35.00            23
# 25  26         Correa trapezoidal     Negro    4.80             4
# 26  27              Polea dentada  Plateado    6.20             6
# 27  28            Soporte angular     Negro    3.50            24
# 28  29                Guía lineal  Plateado   28.00            25
# 29  30         Carril de rodadura      Gris   19.99            26
# 30  31         Cojinete de agujas  Plateado    5.60             5
# 31  32         Acoplador flexible     Negro    8.25            27
# 32  33             Sello mecánico     Negro    6.80             3
# 33  34         Cilindro neumático  Plateado   24.50            28
# 34  35          Válvula solenoide      Azul   16.75             9
# 35  36        Manómetro analógico    Blanco   11.20            29
# 36  37     Transductor de presión      Gris   32.00            30
# 37  38            Termopar tipo K  Amarillo    9.40            31
# 38  39       Convertidor de señal     Negro   18.90            32
# 39  40           Relé de potencia     Negro    5.60            33
# 40  41  Condensador electrolítico      Azul    1.20            34
# 41  42           Resistencia 10KΩ      Café    0.15            35
# 42  43       Potenciómetro lineal      Gris    2.80            36
# 43  44        Display 7 segmentos     Verde    1.90            37
# 44  45                  Zócalo IC     Negro    0.40            38
# 45  46          Placa de circuito     Verde    3.20            13
# 46  47               Conector USB     Negro    1.75            12
# 47  48          Transformador 12V     Negro    8.90            39
# 48  49     Fuente de alimentación     Negro   15.00            40
# 49  50                 Batería 9V     Negro    4.50            41

# %%
def crear_esquema_completo():

    conn = sqlite3.connect('database_team_5.db')
    cursor = conn.cursor()

# %%
import sqlite3
import pandas as pd


def crear_esquema_completo():

    conn = sqlite3.connect('database_team_5.db')
    cursor = conn.cursor()
    
    try:
        
        cursor.execute("""
        CREATE TABLE IF NOT EXISTS Categoria (
            ID INTEGER PRIMARY KEY AUTOINCREMENT,
            Nombre TEXT NOT NULL UNIQUE
        );
        """)
        
        
        categorias = [
            (1, 'Tornillería'),
            (2, 'Resortes'),
            (3, 'Juntas'),
            (4, 'Correas'),
            (5, 'Rodamientos'),
            (6, 'Engranajes'),
            (7, 'Ejes'),
            (8, 'Bujes'),
            (9, 'Válvulas'),
            (10, 'Sensores'),
            (11, 'Cables'),
            (12, 'Conectores'),
            (13, 'Circuitos'),
            (14, 'Refrigeración'),
            (15, 'Ventiladores'),
            (16, 'Filtros'),
            (17, 'Bombas'),
            (18, 'Termostatos'),
            (19, 'Interruptores'),
            (20, 'Fusibles'),
            (21, 'LEDs'),
            (22, 'Motores'),
            (23, 'Reductores'),
            (24, 'Soportes'),
            (25, 'Guias'),
            (26, 'Rieles'),
            (27, 'Acopladores'),
            (28, 'Cilindros'),
            (29, 'Manómetros'),
            (30, 'Transductores'),
            (31, 'Termopares'),
            (32, 'Convertidores'),
            (33, 'Relés'),
            (34, 'Condensadores'),
            (35, 'Resistencias'),
            (36, 'Potenciómetros'),
            (37, 'Displays'),
            (38, 'Zócalos'),
            (39, 'Transformadores'),
            (40, 'Fuentes'),
            (41, 'Baterías')
        ]
        
        cursor.executemany("INSERT OR IGNORE INTO Categoria (ID, Nombre) VALUES (?, ?)", categorias)
        
       
        cursor.execute("PRAGMA foreign_keys = ON")  
        
        
        cursor.execute("""
        SELECT COUNT(*) FROM pragma_table_info('Pieza') 
        WHERE name = 'ID_Categoria'
        """)
        if cursor.fetchone()[0] == 0:
            
            cursor.execute("""
            ALTER TABLE Pieza 
            ADD COLUMN ID_Categoria INTEGER REFERENCES Categoria(ID)
            """)
        
        conn.commit()
        print("Esquema completo creado:")
        print("- Tabla Categoria con 41 categorías")
        print("- Relación con tabla Pieza establecida")
        
    except Exception as e:
        print(f" Error: {e}")
    finally:
        conn.close()

def ver_datos_completos():
    conn = sqlite3.connect('database_team_5.db')
    
    try:
        # Consulta JOIN para ver piezas con sus categorías
        query = """
        SELECT p.ID, p.Nombre, p.Color, p.Precio, c.Nombre as Categoria
        FROM Pieza p
        LEFT JOIN Categoria c ON p.ID_Categoria = c.ID
        """
        
        df = pd.read_sql(query, conn)
        
        print("\nTabla completa de Piezas con Categorías:")
        
        print("\nResumen por categoría:")
        resumen = pd.read_sql("""
        SELECT c.Nombre as Categoria, COUNT(p.ID) as Cantidad, 
               AVG(p.Precio) as Precio_Promedio
        FROM Categoria c
        LEFT JOIN Pieza p ON c.ID = p.ID_Categoria
        GROUP BY c.Nombre
        """, conn)
        
        
    except Exception as e:
        print(f" Error: {e}")

# %%
query = """
SELECT p.ID, p.Nombre, p.Color, p.Precio, c.Nombre as Categoria
FROM Pieza p
LEFT JOIN Categoria c ON p.ID_Categoria = c.ID
"""
df = pd.read_sql(query, conn)

# %%
df
# Out:
#     ID                     Nombre     Color  Precio        Categoria
# 0    1         Tornillo hexagonal  Plateado    0.50      Tornillería
# 1    2            Tuerca estándar  Plateado    0.30      Tornillería
# 2    3             Arandela plana  Plateado    0.20      Tornillería
# 3    4         Resorte helicoidal  Plateado    1.20         Resortes
# 4    5               Junta tórica     Negro    0.80           Juntas
# 5    6             Correa dentada     Negro    5.99          Correas
# 6    7        Rodamiento de bolas      Gris    8.50      Rodamientos
# 7    8            Engranaje recto  Plateado    3.75       Engranajes
# 8    9         Eje de transmisión     Negro   12.00             Ejes
# 9   10             Buje de bronce    Dorado    4.25            Bujes
# 10  11       Válvula de retención      Rojo    7.80         Válvulas
# 11  12      Sensor de temperatura    Blanco   15.99         Sensores
# 12  13            Cable eléctrico     Negro    2.50           Cables
# 13  14              Conector RJ45      Azul    1.20       Conectores
# 14  15                 Placa base     Verde   25.00        Circuitos
# 15  16         Disipador de calor     Negro    6.40    Refrigeración
# 16  17           Ventilador axial     Negro    9.99     Ventiladores
# 17  18             Filtro de aire    Blanco    3.25          Filtros
# 18  19              Bomba de agua     Negro   18.50           Bombas
# 19  20                 Termostato    Blanco    7.20      Termostatos
# 20  21     Interruptor de palanca      Rojo    2.10    Interruptores
# 21  22                Fusible 10A  Amarillo    0.75         Fusibles
# 22  23                   LED rojo      Rojo    0.30             LEDs
# 23  24          Motor paso a paso     Negro   22.00          Motores
# 24  25      Reductor de velocidad      Gris   35.00       Reductores
# 25  26         Correa trapezoidal     Negro    4.80          Correas
# 26  27              Polea dentada  Plateado    6.20       Engranajes
# 27  28            Soporte angular     Negro    3.50         Soportes
# 28  29                Guía lineal  Plateado   28.00            Guias
# 29  30         Carril de rodadura      Gris   19.99           Rieles
# 30  31         Cojinete de agujas  Plateado    5.60      Rodamientos
# 31  32         Acoplador flexible     Negro    8.25      Acopladores
# 32  33             Sello mecánico     Negro    6.80           Juntas
# 33  34         Cilindro neumático  Plateado   24.50        Cilindros
# 34  35          Válvula solenoide      Azul   16.75         Válvulas
# 35  36        Manómetro analógico    Blanco   11.20       Manómetros
# 36  37     Transductor de presión      Gris   32.00    Transductores
# 37  38            Termopar tipo K  Amarillo    9.40       Termopares
# 38  39       Convertidor de señal     Negro   18.90    Convertidores
# 39  40           Relé de potencia     Negro    5.60            Relés
# 40  41  Condensador electrolítico      Azul    1.20    Condensadores
# 41  42           Resistencia 10KΩ      Café    0.15     Resistencias
# 42  43       Potenciómetro lineal      Gris    2.80   Potenciómetros
# 43  44        Display 7 segmentos     Verde    1.90         Displays
# 44  45                  Zócalo IC     Negro    0.40          Zócalos
# 45  46          Placa de circuito     Verde    3.20        Circuitos
# 46  47               Conector USB     Negro    1.75       Conectores
# 47  48          Transformador 12V     Negro    8.90  Transformadores
# 48  49     Fuente de alimentación     Negro   15.00          Fuentes
# 49  50                 Batería 9V     Negro    4.50         Baterías

# %%
conn.close()
